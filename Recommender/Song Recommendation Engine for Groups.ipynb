# %% [markdown]
# # Song Recommendation Engine for Groups
#
# There are many recommendation models out there that can take a list of songs that a particular user has liked and then output recommended songs for that users. However, our objective is different. Our final goal is to create a machine learning model that can recommend songs that are likely to garner the most positive feedback from a $group$ of individuals at a party, each with unique tastes in music.
#
# In order to do this, we need to develop a pipeline that takes a set of users and the songs they interacted with and then outputs a list of recommended songs for the entire group.

# %% [markdown]
# Note that we are creating a pipeline. So, this means that we cannot pre-train our model; the clusters are going to be different for every group. The model will have to train live, during the party.

# %% [markdown]
# ## Loading the Spotify Dataset

# %% [markdown]
# To build the pipeline, we will use the Spotify dataset of a million playlists and the songs in them. In real life, parties will likely have around 10 people, so we will consider 10 random playlists in the dataset. Note that each playlist can be treated as a unique person, with the songs in it corresponding to a user's upvotes.

# %%
# import some necessary libraries

import sys
import spotipy
import spotipy.util as util

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# dataframe settings
pd.set_option('display.max_columns', 50)

# %%
# load the data
original_df = pd.read_csv("0-999_playlists.csv")

# %%
original_df
# Out:
#                                     trackid          artist_name  \
# 0      spotify:track:0UaMYEvWZi0ZqiDOoHU3YI        Missy Elliott
# 1      spotify:track:6I9VzXrHxO9rA9A5euc8Ak       Britney Spears
# 2      spotify:track:0WqIKmW4BTrj3eJFmnCKMv              Beyoncé
# 3      spotify:track:1AWQoqb9bSvzTjaLralEkT    Justin Timberlake
# 4      spotify:track:1lzr43nnXAijIGYnCT8M8H               Shaggy
# 5      spotify:track:0XUfyU2QviPAs6bxSpXYG4                Usher
# 6      spotify:track:68vgtRHr7iZHpzGpon6Jlo                Usher
# 7      spotify:track:3BxWKCI06eQ5Od8TY2JBeA   The Pussycat Dolls
# 8      spotify:track:7H6ev70Weq6DdpZyyTmUXk      Destiny's Child
# 9      spotify:track:2PpruBYCo4H7WOBJ7Q2EwM              OutKast
# 10     spotify:track:2gam98EZKrF9XuOkU13ApN        Nelly Furtado
# 11     spotify:track:4Y45aqo9QMa57rDsAJv40A      Jesse McCartney
# 12     spotify:track:1HwpWwa6bnqqRhK8agG4RS      Jesse McCartney
# 13     spotify:track:20ORwCJusz4KS2PbTPVNKo      Jesse McCartney
# 14     spotify:track:7k6IzwMGpxnRghE7YosnXT               Cassie
# 15     spotify:track:1Bv0Yl01xBDZD4OQP93fyl              Omarion
# 16     spotify:track:4omisSlTk6Dsq2iQD7MA07        Avril Lavigne
# 17     spotify:track:7xYnUQigPoIDAMPVK79NEq          Chris Brown
# 18     spotify:track:6d8A5sAx9TfdeseDvfWNHd              Beyoncé
# 19     spotify:track:4pmc2AxSEq6g7hPVlJCPyP      Destiny's Child
# 20     spotify:track:215JYyyUnrJ98NK3KEwu6d          Sheryl Crow
# 21     spotify:track:0uqPG793dkDDN7sCUJJIVC  The Black Eyed Peas
# 22     spotify:track:19Js5ypV6JKn4DMExHQbGc     Bowling For Soup
# 23     spotify:track:1JURww012QnWAw0zZXi6Aa       The Click Five
# 24     spotify:track:7DFnq8FYhHMCylykf6ZCxA          Chris Brown
# 25     spotify:track:1TfAhjzRBWzYZ8IdUV3igl       Jonas Brothers
# 26     spotify:track:1Y4ZdPOOgCUhBcKZOrUFiS             Lil Mama
# 17                                          Run It!    0
# 18          Check On It - feat. Bun B and Slim Thug    0
# 19                                 Jumpin', Jumpin'    0
# 20                                  Soak Up The Sun    0
# 21                               Where Is The Love?    0
# 22                                      Stacy's Mom    0
# 23                                    Just The Girl    0
# 24                              Yo (Excuse Me Miss)    0
# 25                                        Year 3000    0
# 26                                        Lip Gloss    0
# 27                  Everytime We Touch - Radio Edit    0
# 28                                      Whatcha Say    0
# 29                                 Miss Independent    0
# ...                                             ...  ...
# 67473                       The Very Thought of You  999
# 67474                                       Neptune  999
# 67475                        I Love How You Love Me  999
# 67476                                 Light Outside  999
# 67477                                      Our Song  999
# 67478                                 that one song  999
# 67479                                    fuck me up  999
# 67480                         fragile (feat. WRENN)  999
# 67481                                    Lift Me Up  999
# 67482                                 Stuck With Me  999
# 67483                                         Paris  999
# 67484                                        Asking  999
# 67485                               You're the Best  999
# 67486                                        Alaska  999
# 67487                           U Make Me Feel Good  999
# 67488                                    Oh My Love  999
# 67489                                 Fallingforyou  999
# 67490                                  Close To You  999
# 67491                                La Vie En Rose  999
# 67492  On An Evening In Roma (Sott'er Celo De Roma)  999
# 67493                                       Fragile  999
# 67494                                 Diamond Child  999
# 67495         Comptine d'un autre été, l'après-midi  999
# 67496                                  I Don't Know  999
# 67497                                           Ivy  999
# 67498                          Say You Won't Let Go  999
# 67499                                    The Answer  999
# 67500                                         25.22  999
# 67501                                  Good Feeling  999
# 67502  Cosmic Angel - Acoustic From Capitol Studios  999
#
# [67503 rows x 4 columns]

# %% [markdown]
# It is important to keep in mind that data from the app will be coming into this pipeline with the following two relevant columns:
#
# $\text{username | upvoted_song_trackid}$
#
# as the upvotes are cast. The app will only send the 5 (or less, if the user has not cast 5 upvotes yet) most recent upvoted tracks of each user.
#
# Hence, we should manipulate this data frame to match our pipeline input.

# %%
pipeline_df = original_df[['pid', 'trackid']]

# %%
pipeline_df
# Out:
#        pid                               trackid
# 0        0  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# 1        0  spotify:track:6I9VzXrHxO9rA9A5euc8Ak
# 2        0  spotify:track:0WqIKmW4BTrj3eJFmnCKMv
# 3        0  spotify:track:1AWQoqb9bSvzTjaLralEkT
# 4        0  spotify:track:1lzr43nnXAijIGYnCT8M8H
# 5        0  spotify:track:0XUfyU2QviPAs6bxSpXYG4
# 6        0  spotify:track:68vgtRHr7iZHpzGpon6Jlo
# 7        0  spotify:track:3BxWKCI06eQ5Od8TY2JBeA
# 8        0  spotify:track:7H6ev70Weq6DdpZyyTmUXk
# 9        0  spotify:track:2PpruBYCo4H7WOBJ7Q2EwM
# 10       0  spotify:track:2gam98EZKrF9XuOkU13ApN
# 11       0  spotify:track:4Y45aqo9QMa57rDsAJv40A
# 12       0  spotify:track:1HwpWwa6bnqqRhK8agG4RS
# 13       0  spotify:track:20ORwCJusz4KS2PbTPVNKo
# 14       0  spotify:track:7k6IzwMGpxnRghE7YosnXT
# 15       0  spotify:track:1Bv0Yl01xBDZD4OQP93fyl
# 16       0  spotify:track:4omisSlTk6Dsq2iQD7MA07
# 17       0  spotify:track:7xYnUQigPoIDAMPVK79NEq
# 18       0  spotify:track:6d8A5sAx9TfdeseDvfWNHd
# 19       0  spotify:track:4pmc2AxSEq6g7hPVlJCPyP
# 20       0  spotify:track:215JYyyUnrJ98NK3KEwu6d
# 11            0  spotify:track:4Y45aqo9QMa57rDsAJv40A
# 12            0  spotify:track:1HwpWwa6bnqqRhK8agG4RS
# 13            0  spotify:track:20ORwCJusz4KS2PbTPVNKo
# 14            0  spotify:track:7k6IzwMGpxnRghE7YosnXT
# 15            0  spotify:track:1Bv0Yl01xBDZD4OQP93fyl
# 16            0  spotify:track:4omisSlTk6Dsq2iQD7MA07
# 17            0  spotify:track:7xYnUQigPoIDAMPVK79NEq
# 18            0  spotify:track:6d8A5sAx9TfdeseDvfWNHd
# 19            0  spotify:track:4pmc2AxSEq6g7hPVlJCPyP
# 20            0  spotify:track:215JYyyUnrJ98NK3KEwu6d
# 21            0  spotify:track:0uqPG793dkDDN7sCUJJIVC
# 22            0  spotify:track:19Js5ypV6JKn4DMExHQbGc
# 23            0  spotify:track:1JURww012QnWAw0zZXi6Aa
# 24            0  spotify:track:7DFnq8FYhHMCylykf6ZCxA
# 25            0  spotify:track:1TfAhjzRBWzYZ8IdUV3igl
# 26            0  spotify:track:1Y4ZdPOOgCUhBcKZOrUFiS
# 27            0  spotify:track:6MjljecHzHelUDismyKkba
# 28            0  spotify:track:67T6l4q3zVjC5nZZPXByU8
# 29            0  spotify:track:34ceTg8ChN5HjrqiIYCn9Q
# ...         ...                                   ...
# 67473       999  spotify:track:7jxYkSGQdhdDD940NdxiSv
# 67474       999  spotify:track:2GiFSPEnjXiHfQtQOuuLly
# 67475       999  spotify:track:0wdRsrWCjLQPQpYAlh86p8
# 67476       999  spotify:track:7du4OH1Ld78PJhC8fDLUJO
# 67477       999  spotify:track:3pvHEWAY1XrI5bctqEPcPB
# 67478       999  spotify:track:1lgWOtohsjX526FK6Ch5B8
# 67479       999  spotify:track:50J9NhjECm19ZBadwJembA
# 67480       999  spotify:track:1KKjApPXuCsMKfds56XD1Y
# 67481       999  spotify:track:1bX27QQuIxzo3Lso2nTHpg
# 67482       999  spotify:track:3nMIGUBmSu9QN6SzPLRQeg
# 67483       999  spotify:track:3kbjhJgBeA9KuAu0Y1CwIa
# 67484       999  spotify:track:6BPHmElfRujFRYTzwfQHT8
# 67485       999  spotify:track:6dHrWj35HXTGvlCasE5VAA
# 67486       999  spotify:track:4DyfJFTQb27adTDdhFeSgD
# 67487       999  spotify:track:6nvThTphqHGVhBffov6TaV
# 67488       999  spotify:track:0KMrYUEfexgam36li6d9F0
# 67489       999  spotify:track:2TgxCUZdHFkPEVmFge1OSd
# 67490       999  spotify:track:4gFxywaJejXWxo0NjlWzgg
# 67491       999  spotify:track:0VxocBntP1XTZRsR9ZURPS
# 67492       999  spotify:track:16pUlUFjyp6BtDtxC0i9ch
# 67493       999  spotify:track:4e7E3rBA7axwmPmCc0I2XA
# 67494       999  spotify:track:1msfqzqHggvi1mlCT4Z7O5
# 67495       999  spotify:track:3YYKrn3iGOAel605Znt3ai
# 67496       999  spotify:track:3uCHI1gfOUL5j5swEh0TcH
# 67497       999  spotify:track:2ZWlPOoWh0626oTaHrnl2a
# 67498       999  spotify:track:5uCax9HTNlzGybIStD3vDh
# 67499       999  spotify:track:0P1oO2gREMYUCoOkzYAyFu
# 67500       999  spotify:track:2oM4BuruDnEvk59IvIXCwn
# 67501       999  spotify:track:4Ri5TTUgjM96tbQZd5Ua7V
# 67502       999  spotify:track:5RVuBrXVLptAEbGJdSDzL5
#
# [67503 rows x 2 columns]

# %% [markdown]
# Now, we will choose 10 random usernames to consider as the people in our party.

# %%
from random import sample
number_of_playlists_to_select = 10
random_usernames = sample(range(0, 1000), number_of_playlists_to_select)
random_usernames.sort()

print(random_usernames)

pipeline_df_shortened = pd.DataFrame(columns = ['username', 'trackid'])
count = 0
for index, row in pipeline_df.iterrows():
    if (row['username'] in random_usernames):
        pipeline_df_shortened.loc[count] = row
        count = count + 1
# Out:
# [5, 167, 192, 306, 467, 472, 516, 648, 731, 797]

# %%
pipeline_df_shortened
# Out:
#     username                               trackid
# 0          5  spotify:track:61LtVmmkGr8P9I2tSPvdpf
# 1          5  spotify:track:5Q0Nhxo0l2bP3pNjpGJwV1
# 2          5  spotify:track:1V4jC0vJ5525lEF1bFgPX2
# 3          5  spotify:track:3XVozq1aeqsJwpXrEZrDJ9
# 4          5  spotify:track:6eE6akYdf9w2rZUOIMwSgw
# 5          5  spotify:track:0CAfXk7DXMnon4gLudAp7J
# 6          5  spotify:track:5bitEcj72xFL3yv9ZS5fkE
# 7          5  spotify:track:4Ow5x7P5NAAR1jPoskudoA
# 8          5  spotify:track:3S2R0EVwBSAVMd5UMgKTL0
# 9          5  spotify:track:7MCNnnmwm7TXMh7xyNGohi
# 10         5  spotify:track:0XUfyU2QviPAs6bxSpXYG4
# 11         5  spotify:track:12lZTPlXwUtrQuhEty6098
# 12         5  spotify:track:3Xv5C02Wxlek0dmrYAM5A8
# 13         5  spotify:track:3zByVQLvdXUaDTubfWkpCk
# 14         5  spotify:track:07Tx168RSsUS1HqkDIOZbH
# 15         5  spotify:track:1dzQoRqT5ucxXVaAhTcT0J
# 16         5  spotify:track:0jDWRUbxSn8zQlwFbeLHwo
# 17         5  spotify:track:0DiWol3AO6WpXZgp0goxAV
# 18         5  spotify:track:1dzQoRqT5ucxXVaAhTcT0J
# 19         5  spotify:track:6ebkx7Q5tTxrCxKq4GYj0Y
# 20         5  spotify:track:4QNpBfC0zvjKqPJcyqBy9W
# 21         5  spotify:track:7mitXLIMCflkhZiD34uEQI
# 22         5  spotify:track:6qn9YLKt13AGvpq9jfO8py
# 23         5  spotify:track:0VZ9xPNa6ROafP6GYYuv2S
# 24         5  spotify:track:3H1LCvO3fVsK2HPguhbml0
# 25         5  spotify:track:1oHNvJVbFkexQc0BpQp7Y4
# 26         5  spotify:track:0CmIALzGn4vHIHJG4n3Q4z
# 27         5  spotify:track:5uuJruktM9fMdN9Va0DUMl
# 28         5  spotify:track:5qnk7XRdHF0OLUVexVaRCp
# 29         5  spotify:track:682nhC3aQtY9HwrC2P2vz4
# ..       ...                                   ...
# 932      797  spotify:track:5lS7KHsdvkMJp8eASqZWzb
# 933      797  spotify:track:1n8ZUpQ0iVY6gVBgEUdA2Q
# 934      797  spotify:track:6nHBJFQz4gsK2Q6RIpBD0M
# 935      797  spotify:track:3PSLF6EouJWkd6Tbyg9pJq
# 936      797  spotify:track:2HR3ImMiIJAnf1Dl8x9mP8
# 937      797  spotify:track:6520aj0B4FSKGVuKNsOCOi
# 938      797  spotify:track:6tEfE6AC7sc2rN6q2QtPvc
# 939      797  spotify:track:0gbBzIqrECJOEPvQJIBFs5
# 940      797  spotify:track:6Wxj0FQMAJXOWgRbyFP5f8
# 941      797  spotify:track:2mfUa8bLs2s5N4VaqJZ4lZ
# 942      797  spotify:track:1o2DMB5ZGoKV767eMx8bPf
# 943      797  spotify:track:7FCfMXYTIiQ9b4hDYs4Iol
# 944      797  spotify:track:5KeyVNymqfqac1wLDseK8v
# 945      797  spotify:track:6uAm7pG66O1XesXS9bpHSF
# 946      797  spotify:track:1UZOjK1BwmwWU14Erba9CZ
# 947      797  spotify:track:5y20ik4oFXCIg1santQtWl
# 948      797  spotify:track:4wreHWQnFC0zhJ4Xtlj3hA
# 949      797  spotify:track:1Vv0MPcooEoQzVZYfKMgKW
# 950      797  spotify:track:3QzbEvmnuZIONNv82PylZb
# 951      797  spotify:track:6xIkmrDfxXnaj0oU5o88zk
# 952      797  spotify:track:0CokSRCu5hZgPxcZBaEzVE
# 953      797  spotify:track:1x5sYLZiu9r5E43kMlt9f8
# 954      797  spotify:track:1g1TeDflB6atAy7HKwrzXu
# 955      797  spotify:track:11EOvxJRG665bwRU0z6YVa
# 956      797  spotify:track:3m660poUr1chesgkkjQM7P
# 957      797  spotify:track:1FgmP7AOTcn7MGYmImj0kn
# 958      797  spotify:track:6w40GgWhGts8g6779DPXR3
# 959      797  spotify:track:6iCJCZqDJjmBxt07Oid6FI
# 960      797  spotify:track:1JuChOEPH0Rceq573FGQSK
# 961      797  spotify:track:1rTMTobUIpsgQdpTFFgLok
#
# [962 rows x 2 columns]

# %% [markdown]
# Next, for each user, we will randomly select between 1 to 5 of its songs to keep in the dataframe in order to mimic the fact that this pipeline will be receiving the five (or less) most recently upvoted tracks of the user.

# %%
from random import randrange

input_df = pd.DataFrame(columns = ['username', 'trackid'])

for user in random_usernames:
    mini_df = pipeline_df_shortened[pipeline_df_shortened.username == user]
    num_tracks_user = randrange(1,6) # we will randomly choose between 1 and 5 (inclusive) of the user's tracks
    mini_df = mini_df.sample(num_tracks_user)
    input_df = input_df.append(mini_df, ignore_index = True)

# %%
input_df
# Out:
#    username                               trackid
# 0         5  spotify:track:5xS9hkTGfxqXyxX6wWWTt4
# 1         5  spotify:track:70cTMpcgWMcR18t9MRJFjB
# 2       167  spotify:track:6U8EShYiwNNrGogCxTeFm2
# 3       167  spotify:track:5LxQohFfm9A4V1VSTS1RDG
# 4       167  spotify:track:1dD1aarWotVIiFo5gGdMc2
# 5       192  spotify:track:0ESJlaM8CE1jRWaNtwSNj8
# 6       192  spotify:track:5w1vhNA2OEWUQ371QzyMmM
# 7       192  spotify:track:2ZBfTcQM9S3yTLKhHrvCnQ
# 8       192  spotify:track:2Fe6gDE0mCZz0g98i5QpVL
# 9       192  spotify:track:3a1lNhkSLSkpJE4MSHpDu9
# 10      306  spotify:track:7wGoVu4Dady5GV0Sv4UIsx
# 11      306  spotify:track:77IAeEz8LEchPN8UNjaTJ2
# 12      306  spotify:track:1vvnYpYEMVB4aq9I6tHIEB
# 13      306  spotify:track:16qYlQ6koFxYVbiJbGHblz
# 14      306  spotify:track:2fQrGHiQOvpL9UgPvtYy6G
# 15      467  spotify:track:1ffRRgFiA0uVMHsjR8Ksuf
# 16      472  spotify:track:6XK6Zw6JkFsHXzAcMWNiIr
# 17      472  spotify:track:00DYRuYJQzfI6dH4Adkimo
# 18      472  spotify:track:748pETtPvRIotGU9N3FgXH
# 19      516  spotify:track:4htbAEZWr53J08x3dUv00W
# 20      516  spotify:track:455HSLQfOn9vxG6UjzoTWw
# 21      516  spotify:track:0WqIKmW4BTrj3eJFmnCKMv
# 22      648  spotify:track:24cKN8P2uGWypxTw5WaNlq
# 23      648  spotify:track:6miou5rcSI3TqJWTKizJJI
# 24      648  spotify:track:69uJi5QsBtqlYkGURTBli8
# 25      648  spotify:track:3Pr70knS8uTSiKbwf4rGav
# 26      648  spotify:track:5Q30xdABnojqN3wBIhrsQp
# 27      731  spotify:track:26NQzsYvTbSutlj2i4ILXW
# 28      797  spotify:track:4iMwTDfXQDdEWyI1dtx9K8
# 29      797  spotify:track:6875MeXyCW0wLyT72Eetmo
# 30      797  spotify:track:1n8ZUpQ0iVY6gVBgEUdA2Q
# 31      797  spotify:track:1UZOjK1BwmwWU14Erba9CZ
# 32      797  spotify:track:5WSdMcWTKRdN1QYVJHJWxz

# %% [markdown]
# ## Feature Extraction

# %% [markdown]
# Note: input_df needs to have at least 6 rows. If there are $\le 5$ rows, the tracks can be directly inputted into the Spotify API's recommendation engine as seed tracks (which takes a maximum of 5 seeds). It is not possible to identify structures in the music tastes of a group with $\le 5$ tracks upvoted.
#
# Now, for each track, we need to get the Spotify audio features for it that can be useful for clustering.
#
# - danceability
# - energy
# - speechiness
# - acousticness
# - instrumentalness
# - valence

# %%
# set up Spotipy object

import os
from json.decoder import JSONDecodeError

scope = 'user-read-email'
username = 'musicrg1'

try:
    token = util.prompt_for_user_token(username, scope, client_id='13734e89943a4249864bb67a9fdd3f9f', client_secret='f4046fa141c24926b3ee730529ffcf2b', redirect_uri='google.com')
except (AttributeError, JSONDecodeError):
    os.remove(f".cache-{username}")
    token = util.prompt_for_user_token(username, scope, client_id='13734e89943a4249864bb67a9fdd3f9f', client_secret='f4046fa141c24926b3ee730529ffcf2b', redirect_uri='google.com')
    
# token = util.prompt_for_user_token(scope,client_id,client_secret,redirect_uri='https://google.com')

if token:
    spot = spotipy.Spotify(auth=token)
else:
    print("Can't get token for", username)

# %%
# create new dataframe with columns including the audio features
df_final = pd.DataFrame(columns = ['username', 'trackid', 'danceability', 'energy', 'speechiness', 'acousticness', 'instrumentalness', 'valence'])

# %%
df_final
# Out:
# Empty DataFrame
# Columns: [username, trackid, danceability, energy, speechiness, acousticness, instrumentalness, valence]
# Index: []

# %%
# Now, we can actually get the audio features for the various tracks
df_final.reset_index() # safety first!
count = 0
for index, row in input_df.iterrows():
    track_audio_features = spot.audio_features(row['trackid'])[0] # take first element (which is a dict) since we are only inputting one song into audio features function
    new_row = [row['username'], row['trackid'], track_audio_features['danceability'], track_audio_features['energy'], track_audio_features['speechiness'], track_audio_features['acousticness'], track_audio_features['instrumentalness'], track_audio_features['valence']]
    print(new_row)
    df_final.loc[count] = new_row
    count = count + 1
# Out:
# 23      648  spotify:track:6miou5rcSI3TqJWTKizJJI         0.829   0.669
# 24      648  spotify:track:69uJi5QsBtqlYkGURTBli8         0.588   0.149
# 25      648  spotify:track:3Pr70knS8uTSiKbwf4rGav         0.689   0.441
# 26      648  spotify:track:5Q30xdABnojqN3wBIhrsQp         0.303   0.319
# 27      731  spotify:track:26NQzsYvTbSutlj2i4ILXW         0.602   0.793
# 28      797  spotify:track:4iMwTDfXQDdEWyI1dtx9K8         0.469   0.690
# 29      797  spotify:track:6875MeXyCW0wLyT72Eetmo         0.668   0.613
# 30      797  spotify:track:1n8ZUpQ0iVY6gVBgEUdA2Q         0.610   0.707
# 31      797  spotify:track:1UZOjK1BwmwWU14Erba9CZ         0.573   0.781
# 32      797  spotify:track:5WSdMcWTKRdN1QYVJHJWxz         0.657   0.913
#
#     speechiness  acousticness instrumentalness  valence
# 0        0.0651      0.026700                0   0.5230
# 1        0.0265      0.087300                0   0.6100
# 2        0.2140      0.629000                0   0.3370
# 3        0.0411      0.642000                0   0.2880
# 4        0.0281      0.618000                0   0.2980
# 5        0.1450      0.240000                0   0.4950
# 6        0.0639      0.002430         5.43e-05   0.3230
# 7        0.0744      0.040800                0   0.4060
# 8        0.3290      0.013900                0   0.4560
# 9        0.0363      0.215000                0   0.4920
# 10       0.0984      0.130000         9.03e-05   0.1190
# 11       0.3110      0.218000         0.000237   0.6000
# 12       0.3630      0.378000         7.09e-05   0.4940
# 13       0.2670      0.331000         8.67e-06   0.3040
# 14       0.3510      0.015100         7.04e-06   0.3760
# 15       0.0284      0.683000                0   0.2980
# 16       0.0815      0.136000         1.01e-05   0.7300
# 17       0.0384      0.002160         5.15e-05   0.6820
# 18       0.0606      0.024900                0   0.5470
# 19       0.0405      0.306000         1.72e-06   0.7050
# 20       0.0305      0.346000                0   0.9530
# 21       0.2100      0.002380                0   0.7010
# 22       0.0307      0.206000                0   0.2350
# 23       0.0608      0.054700                0   0.5800
# 24       0.0319      0.846000         9.65e-05   0.1130
# 25       0.0278      0.399000                0   0.4370
# 26       0.0282      0.650000           0.0306   0.1780
# 27       0.0623      0.000078            0.139   0.5830
# 28       0.0440      0.086900           0.0021   0.0357
# 29       0.1020      0.414000                0   0.4980
# 30       0.0579      0.358000                0   0.6690
# 31       0.0555      0.076700         2.64e-05   0.3430
# 32       0.0528      0.003920          0.00149   0.9060

# %% [markdown]
# Now that we have our data in a nice format, we can go ahead and build some models that recommend songs to the party.

# %% [markdown]
# ## Model 1

# %% [markdown]
# This model will take all of the songs that have been upvoted by all users, take their average (in terms of the 6 audio features), and then use the Spotify API recommendation engine to recommend 100 songs to the group.

# %%
# get averages for different audio features

avg_danceability = df_final['danceability'].mean()
avg_energy = df_final['energy'].mean()
avg_speechiness = df_final['speechiness'].mean()
avg_acousticness = df_final['acousticness'].mean()
avg_instrumentalness = df_final['instrumentalness'].mean()
avg_valence = df_final['valence'].mean()

# %%
# randomly select 5 tracks as seeds from the dataframe
seeds = df_final['trackid'].sample(5).tolist()

# %%
# get the recommendations
num_recs = 100
recommendations_model_1 = spot.recommendations(seed_tracks = seeds, target_danceability = avg_danceability, target_energy = avg_energy, target_speechines = avg_speechiness, target_acousticness = avg_acousticness, target_instrumentalness = avg_instrumentalness, target_valence = avg_valence,  limit = num_recs)
recommendations_model_1_output = [recommendations_model_1['tracks'][i]['uri'] for i in range (num_recs)]

# %%
recommendations_model_1_output
# Out:
# ['spotify:track:75yUmYDFb9tqmeXni8bJ69',
#  'spotify:track:72gv4zhNvRVdQA0eOenCal',
#  'spotify:track:0IUsGxWP18PBAUMhSEyRLO',
#  'spotify:track:62vpWI1CHwFy7tMIcSStl8',
#  'spotify:track:6NUiDZQALrNiDfqDB6ZBaF',
#  'spotify:track:7D4ur1zrmGhTMV0mX25Pbd',
#  'spotify:track:0VhgEqMTNZwYL1ARDLLNCX',
#  'spotify:track:4KW1lqgSr8TKrvBII0Brf8',
#  'spotify:track:7jZ4UZAmg006Qx3rVuF7JI',
#  'spotify:track:7FOJvA3PxiIU0DN3JjQ7jT',
#  'spotify:track:06FCvd7rrRcF3DdvWH5Isp',
#  'spotify:track:5ZiL1WC0SPgNjEYV4eP0I2',
#  'spotify:track:6Bqn71zg1dznO7Ck8ykEWc',
#  'spotify:track:3lSDIJ2abCrOdDJ6pshUap',
#  'spotify:track:5JdSkfCEPPXPRU2QgYZgh6',
#  'spotify:track:0I20rLT2MJDhcF96AjbNYo',
#  'spotify:track:2OEKdLpIhPT11FR746kOoQ',
#  'spotify:track:3ZLyt2ndLFBh148XRYjYYZ',
#  'spotify:track:1wIQtB3UQ1TfjNMZZqO6eh',
#  'spotify:track:6FzjhVjXDoBGfq1sSdNq7S',
#  'spotify:track:1TpeT2PWnAv9NDbqK1qy6J',
#  'spotify:track:4k77gN6nozNqbsFGpAr6ol',
#  'spotify:track:6PmnGYDsruYLBNY4Rpx4t9',
#  'spotify:track:12KG3DCYkxoMUAPWq1uFnw',
#  'spotify:track:1rmDEzJFdjXUQdQQklDWXu',
#  'spotify:track:0Y0TOsE1q11qgbi7c5WZsG',
#  'spotify:track:5NhlpQ6BOIz3S5welptk1W',
#  'spotify:track:23DZLSxCK6kM8FF2RlzKDl',
#  'spotify:track:6NyhBA9M6KK0fuVsojxL00',
#  'spotify:track:7i2DJ88J7jQ8K7zqFX2fW8',
#  'spotify:track:3eR23VReFzcdmS7TYCrhCe',
#  'spotify:track:4oEMnW7vgU1hOYjXqa4sa6',
#  'spotify:track:2Ima72UXnfvR539afL3SAF',
#  'spotify:track:0qLt7pQhm8LDxFgI0YXdlY',
#  'spotify:track:7tkqxOV765aQ6s45fBijjt',
#  'spotify:track:7c54SYCznJZ4XF9hyavpz4',
#  'spotify:track:0GRSF02AmBaMoD7wBiN8Pe',
#  'spotify:track:2YlZnw2ikdb837oKMKjBkW',
#  'spotify:track:4VksxNeObBK9aaWMc6ZXK8',
#  'spotify:track:6cfk99ICcxQrT0s149uFcF',
#  'spotify:track:6vSforRhuzsA0D0SO9fG1S',
#  'spotify:track:3NWcFiL6oCEagrFiTdDr1m',
#  'spotify:track:1u0MOgWF1bbylVxpJG2ZjB',
#  'spotify:track:6amzJ3wmEDf7e5tHAndZmn',
#  'spotify:track:1vvnYpYEMVB4aq9I6tHIEB',
#  'spotify:track:4T4DTut89dSVRnURztj4Xj',
#  'spotify:track:2GieQwEoirGPxp273YJdV6',
#  'spotify:track:2Fe6gDE0mCZz0g98i5QpVL',
#  'spotify:track:1kvGyV4fgzwCXxYfZ2ORiy',
#  'spotify:track:26SBr6NX0lex4f1MMRNJyR',
#  'spotify:track:0Fz3tlzczn9LVKV3Isk2CM']

# %% [markdown]
# However, there is a big downside to this model: it is biased towards users who have upvoted more songs and thus have more rows in the DataFrame than other users. We can fix this issue in our next model.

# %% [markdown]
# ## Model 2

# %% [markdown]
# This model is not a whole lot different than Model 1. All it really does is fix the bias problem. For each user, this model takes their upvoted songs and replaces them with 5 recommended songs for the user. It will take all of the $5k$ songs that have been recommended to the $k$, take their average (in terms of the 6 audio features), and then use the Spotify API recommendation engine to recommend 100 songs to the group.

# %%
# Data frame for storing all the recommended songs for each user
df_final_standardized = pd.DataFrame(columns = ['username', 'trackid', 'danceability', 'energy', 'speechiness', 'acousticness', 'instrumentalness', 'valence'])

# %%
count = 0
for user in random_usernames:
    user_tracks = df_final[df_final.username == user]['trackid'].tolist() # get the user's tracks
    user_5_recs = spot.recommendations(seed_tracks = user_tracks, limit = 5) # get 5 recommendations for the tracks
    user_5_recs_output = [user_5_recs['tracks'][i]['uri'] for i in range (5)] # get the recommendations' track URI's
    user_5_recs_audio_features = spot.audio_features(user_5_recs_output)
    for i in range (5):
        new_standard_row = [user, user_5_recs_output[i], user_5_recs_audio_features[i]['danceability'], user_5_recs_audio_features[i]['energy'], user_5_recs_audio_features[i]['speechiness'], user_5_recs_audio_features[i]['acousticness'], user_5_recs_audio_features[i]['instrumentalness'], user_5_recs_audio_features[i]['valence']]
        print(new_standard_row)
        df_final_standardized.loc[count] = new_standard_row
        count = count + 1
# Out:
# [94, 'spotify:track:0RCgSTkAbohhqEXVxkwBI0', 0.607, 0.737, 0.0263, 0.109, 0, 0.509]
# [94, 'spotify:track:00tB8c71eTcG5jV7PhuF4Q', 0.612, 0.698, 0.0357, 0.248, 3.09e-06, 0.199]
# [94, 'spotify:track:34PsixEmIceg39NpaYxBsH', 0.715, 0.815, 0.0576, 0.0689, 0, 0.804]
# [94, 'spotify:track:6t7Qd7wnEdrNxj1QFUoiss', 0.489, 0.783, 0.0413, 0.0445, 0.000647, 0.542]
# [94, 'spotify:track:081t95JRuDUrQYSS3h8iKk', 0.477, 0.672, 0.0306, 0.049, 0, 0.263]
# [100, 'spotify:track:2dyQtNorA8TdLVxUa947hL', 0.362, 0.512, 0.033, 0.432, 0.955, 0.0805]
# [100, 'spotify:track:0VUXPRlZlAItwGhN4zs2aK', 0.693, 0.642, 0.17, 0.587, 0, 0.903]
# [100, 'spotify:track:1t1ZHTjbDxmwrwtw6CJYaB', 0.779, 0.764, 0.105, 0.0977, 0, 0.765]
# [100, 'spotify:track:4gpTPLGLrKdE1JJVZ2McYD', 0.64, 0.764, 0.066, 0.489, 0, 0.963]
# [100, 'spotify:track:2NW5VMjtynzMn5r4NCTxLY', 0.763, 0.158, 0.166, 0.978, 0.561, 0.885]
# 0        0.0263      0.109000                0   0.5090
# 1        0.0357      0.248000         3.09e-06   0.1990
# 2        0.0576      0.068900                0   0.8040
# 3        0.0413      0.044500         0.000647   0.5420
# 4        0.0306      0.049000                0   0.2630
# 5        0.0330      0.432000            0.955   0.0805
# 6        0.1700      0.587000                0   0.9030
# 7        0.1050      0.097700                0   0.7650
# 8        0.0660      0.489000                0   0.9630
# 9        0.1660      0.978000            0.561   0.8850
# 10       0.0290      0.021300            0.287   0.1940
# 11       0.0790      0.000505            0.351   0.6680
# 12       0.0995      0.057100          0.00021   0.7470
# 13       0.0479      0.011400            0.398   0.9220
# 14       0.0364      0.005580           0.0743   0.8390
# 15       0.1720      0.813000                0   0.5780
# 16       0.0819      0.670000                0   0.5670
# 17       0.0373      0.067300                0   0.9460
# 18       0.0461      0.001420            2e-05   0.5070
# 19       0.2600      0.225000                0   0.7720
# 20       0.1050      0.406000            0.321   0.4930
# 21       0.0323      0.000182         0.000146   0.5610
# 22       0.0695      0.127000         2.94e-06   0.3980
# 23       0.0270      0.475000                0   0.3300
# 24       0.0321      0.350000            0.199   0.1540
# 25       0.1670      0.720000                0   0.7400
# 26       0.0371      0.023700         4.35e-05   0.9370
# 27       0.0600      0.018400            0.053   0.4410
# 28       0.2390      0.044700                0   0.5110
# 29       0.0302      0.893000         2.16e-05   0.1750
# 30       0.0278      0.404000         1.53e-05   0.1740
# 31       0.0371      0.608000                0   0.4900
# 32       0.0359      0.641000                0   0.2380
# 33       0.0409      0.218000                0   0.3180
# 34       0.0367      0.005080                0   0.2240
# 35       0.0321      0.874000            0.908   0.5990
# 36       0.0372      0.846000           0.0781   0.5830
# 37       0.0346      0.907000          0.00124   0.3250
# 38       0.0466      0.992000            0.897   0.0629
# 39       0.0460      0.919000            0.874   0.1920
# 40       0.0593      0.112000                0   0.2470
# 41       0.1330      0.039700                0   0.4730
# 42       0.2690      0.248000                0   0.3280
# 43       0.1300      0.120000                0   0.8300
# 44       0.2190      0.098800                0   0.5970
# 45       0.1350      0.083000                0   0.6930
# 46       0.0331      0.000209         0.000734   0.4480
# 47       0.0438      0.101000            0.354   0.7210
# 48       0.0374      0.191000                0   0.3810
# 49       0.0361      0.122000                0   0.2920

# %%
# get averages for different audio features

avg_danceability = df_final_standardized['danceability'].mean()
avg_energy = df_final_standardized['energy'].mean()
avg_speechiness = df_final_standardized['speechiness'].mean()
avg_acousticness = df_final_standardized['acousticness'].mean()
avg_instrumentalness = df_final_standardized['instrumentalness'].mean()
avg_valence = df_final_standardized['valence'].mean()

# %%
# randomly select 5 tracks as seeds from the dataframe
seeds = df_final_standardized['trackid'].sample(5).tolist()

# %%
# get the recommendations
num_recs = 100
recommendations_model_2 = spot.recommendations(seed_tracks = seeds, target_danceability = avg_danceability, target_energy = avg_energy, target_speechines = avg_speechiness, target_acousticness = avg_acousticness, target_instrumentalness = avg_instrumentalness, target_valence = avg_valence,  limit = num_recs)
recommendations_model_2_output = [recommendations_model_2['tracks'][i]['uri'] for i in range (num_recs)]

# %%
recommendations_model_2_output
# Out:
